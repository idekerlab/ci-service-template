# %% [markdown]
# # Tests for new CI template code
#
# This is a sample script to test new CI template using message exchange.
#
# ## Description
#
# This is a new template code for language-agnostic worker samples.
#
# ## Sample 0: Boilarplate code for calling CI services

# %%
import requests
import json

def jprint(data):
    print(json.dumps(data, indent=4))

# Change this to  your Docker container's IP
BASE = 'http://192.168.99.100/v1/'
HEADERS = {'Content-Type': 'application/json'}

# Check API Status
res = requests.get(BASE + 'services')
jprint(res.json())

# List of sample file locations
small_network = 'https://s3-us-west-2.amazonaws.com/ci-service-data/small.sif'
med_network = 'https://s3-us-west-2.amazonaws.com/ci-service-data/yeastHighQuality.sif'

# Pre-computed kernel and network (HumanNet)
human_net = 'http://chianti.ucsd.edu/~kono/ci/data/HumanNet.v1.symbol.sif'
human_net_kernel = 'http://chianti.ucsd.edu/~kono/ci/data/human_net.kernel.symbol.txt'
# Out:
# [
#     {
#         "serviceName": "kernel",
#         "portNumber": "5556"
#     },
#     {
#         "serviceName": "subnet",
#         "portNumber": "5557"
#     }
# ]

# %% [markdown]
# ## Sample1: Find Subnetwork using pre-computed kernel file

# %%
# Pre-computed kernel and network (HumanNet) stored in UCSD web server (about 0.5 GB)
human_net = 'http://chianti.ucsd.edu/~kono/ci/data/HumanNet.v1.symbol.sif'
human_net_kernel = 'http://chianti.ucsd.edu/~kono/ci/data/human_net.kernel.symbol.txt'

# Specify kernel and SIF file locations
base_query = {
    'kernel_url': human_net_kernel,
    'network_url': human_net,
}

gene_list = ['BRCA1', 'MAPK1']
base_query['query'] = gene_list

res = requests.post(BASE + 'services/subnet', data=json.dumps(base_query), headers=HEADERS)
job_id1 = res.json()['job_id']
jprint(res.json())
# Out:
# {
#     "status": "queued",
#     "job_id": "2a86100e-10e8-4e67-a85d-963339ac3636"
# }

# %%
# Check the status of the job
res = requests.get(BASE + 'queue')
jprint(res.json())
# Out:
# [
#     {
#         "status": "finished",
#         "job_id": "be7cf848-c320-4dea-a386-3f5f2ae071d1"
#     },
#     {
#         "status": "finished",
#         "job_id": "6e7d407c-e66d-4b80-880c-e29827949ab3"
#     },
#     {
#         "status": "finished",
#         "job_id": "7da9c61a-5373-42db-ac68-e75040f6db96"
#     },
#     {
#         "status": "finished",
#         "job_id": "c16aaa12-7c6b-4630-9693-9174c02640c9"
#     },
#     {
#         "status": "finished",
#         "job_id": "dd87063b-d194-4ce6-be05-cac9d7216b7e"
#     },
#     {
#         "status": "finished",
#         "job_id": "2a86100e-10e8-4e67-a85d-963339ac3636"
#     },
#     {
#         "status": "finished",
#         "job_id": "913068c6-833f-4ba3-a329-33e90fcb1a38"
#     },
#     {
#         "status": "finished",
#         "job_id": "547a01e2-4ee1-4861-b403-eeebe9ae26b7"
#     },
#     {
#         "status": "queued",
#         "job_id": "ce0f4d10-b55b-4689-b5aa-db0bf3cdeae2"
#     },
#     {
#         "status": "finished",
#         "job_id": "7627f269-7a79-4e56-9d9c-a970df2298e4"
#     },
#     {
#         "status": "finished",
#         "job_id": "6af7998a-77ca-46db-9c00-7ce5be469827"
#     },
#     {
#         "status": "finished",
#         "job_id": "621df107-7247-4152-a0a0-60e20e70d827"
#     },
#     {
#         "status": "finished",
#         "job_id": "e0f576d2-1010-4e3b-84f5-46d7d9dfaa03"
#     },
#     {
#         "status": "running",
#         "job_id": "b8e5a169-5841-4d7a-923f-5dd857ec8a4a"
#     },
#     {
#         "status": "finished",
#         "job_id": "7db04f9a-2c2d-4657-93ef-45737c3ffd88"
#     },
#     {
#         "status": "running",
#         "job_id": "d890cab7-342e-4fe7-bc03-e1668b634a22"
#     },
#     {
#         "status": "finished",
#         "job_id": "06049454-0349-4952-8cd5-5e3a256f35db"
#     },
#     {
#         "status": "finished",
#         "job_id": "5e363eda-baa5-4e82-82c2-56d7dbcd3c24"
#     }
# ]

# %%
# Get the result (Subnetwork in CX format)
result_url = BASE + 'queue/' + job_id1
print(result_url)
res = requests.get(result_url)
jprint(res.json())
# Out:
# http://192.168.99.100/v1/queue/e0f576d2-1010-4e3b-84f5-46d7d9dfaa03
# [
#     {
#         "nodes": [
#             {
#                 "@id": "_1000"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1000",
#                 "represents": "POLR3G"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1001"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1001",
#                 "represents": "POLR3C"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1000",
#                 "@id": "_1002",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1002",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1003"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1003",
#                 "represents": "CENPF"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1004"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1004",
#                 "represents": "ELK3"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1005",
#                 "target": "_1004"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1005",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1006"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1006",
#                 "represents": "NRG1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1007",
#                 "target": "_1006"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1007",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1008"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1008",
#                 "represents": "ID1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1009",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1009",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1010"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1010",
#                 "represents": "PIAS4"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1011",
#                 "target": "_1010"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1011",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1012"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1012",
#                 "represents": "UIMC1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1013",
#                 "target": "_1012"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1013",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1014"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1014",
#                 "represents": "ATP8B1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1015",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1015",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1016"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1016",
#                 "represents": "POU2F1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1017",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1017",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1018"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1018",
#                 "represents": "LANCL2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1019",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1019",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1020"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1020",
#                 "represents": "NKRF"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1021",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1021",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1022"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1022",
#                 "represents": "SNX6"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1023",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1023",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1024"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1024",
#                 "represents": "RFX3"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1025",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1025",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1026"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1026",
#                 "represents": "NR1H2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1027",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1027",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1028"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1028",
#                 "represents": "VDR"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1029",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1029",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1030"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1030",
#                 "represents": "ZNF24"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1031",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1031",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1032"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1032",
#                 "represents": "RUNX2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1033",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1033",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1034"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1034",
#                 "represents": "TIMELESS"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1035",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1035",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1036"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1036",
#                 "represents": "CIDEA"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1037"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1037",
#                 "represents": "TP73"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1036",
#                 "@id": "_1038",
#                 "target": "_1037"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1038",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1039"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1039",
#                 "represents": "AIFM1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1036",
#                 "@id": "_1040",
#                 "target": "_1039"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1040",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1041",
#                 "target": "_1006"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1041",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1042",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1042",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1043",
#                 "target": "_1010"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1043",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1044",
#                 "target": "_1012"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1044",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1045",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1045",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1046",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1046",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1047",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1047",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1048",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1048",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1049",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1049",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1050",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1050",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1051",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1051",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1052",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1052",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1053",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1053",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1054",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1054",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1004",
#                 "@id": "_1055",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1055",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1056",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1056",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1057",
#                 "target": "_1010"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1057",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1058",
#                 "target": "_1012"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1058",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1059",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1059",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1060",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1060",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1061",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1061",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1062",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1062",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1063",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1063",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1064",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1064",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1065",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1065",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1066",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1066",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1067",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1067",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1068",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1068",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1006",
#                 "@id": "_1069",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1069",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1070"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1070",
#                 "represents": "HSPD1"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1071"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1071",
#                 "represents": "STK26"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1070",
#                 "@id": "_1072",
#                 "target": "_1071"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1072",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1073",
#                 "target": "_1010"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1073",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1074",
#                 "target": "_1012"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1074",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1075",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1075",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1076",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1076",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1077",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1077",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1078",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1078",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1079",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1079",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1080",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1080",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1081",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1081",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1082",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1082",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1083",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1083",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1084",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1084",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1085",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1085",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1086"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1086",
#                 "represents": "JAG2"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1087"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1087",
#                 "represents": "CHRNA10"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1086",
#                 "@id": "_1088",
#                 "target": "_1087"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1088",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1089"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1089",
#                 "represents": "CDCA7"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1086",
#                 "@id": "_1090",
#                 "target": "_1089"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1090",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1091",
#                 "target": "_1012"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1091",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1092",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1092",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1093",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1093",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1094",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1094",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1095",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1095",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1096",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1096",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1097",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1097",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1098",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1098",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1099",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1099",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1100",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1100",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1101",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1101",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1010",
#                 "@id": "_1102",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1102",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1103",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1103",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1104",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1104",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1105",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1105",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1106",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1106",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1107",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1107",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1108",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1108",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1109",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1109",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1110",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1110",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1111",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1111",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1112",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1112",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1113",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1113",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1114",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1114",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1115",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1115",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1116",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1116",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1117",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1117",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1118",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1118",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1119",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1119",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1120",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1120",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1121",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1121",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1122",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1122",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1014",
#                 "@id": "_1123",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1123",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1124",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1124",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1125",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1125",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1126",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1126",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1127",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1127",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1128",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1128",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1129",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1129",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1130",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1130",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1131",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1131",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1016",
#                 "@id": "_1132",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1132",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1133"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1133",
#                 "represents": "ARL8B"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1134"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1134",
#                 "represents": "MIS12"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1133",
#                 "@id": "_1135",
#                 "target": "_1134"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1135",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1136"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1136",
#                 "represents": "RIOK3"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1133",
#                 "@id": "_1137",
#                 "target": "_1136"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1137",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1138",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1138",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1139",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1139",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1140",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1140",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1141",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1141",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1142",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1142",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1143",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1143",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1144",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1144",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1018",
#                 "@id": "_1145",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1145",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1146",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1146",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1147",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1147",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1148",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1148",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1149",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1149",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1150",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1150",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1151",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1151",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1020",
#                 "@id": "_1152",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1152",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1087",
#                 "@id": "_1153",
#                 "target": "_1089"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1153",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1154",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1154",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1155",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1155",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1156",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1156",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1157",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1157",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1158",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1158",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1022",
#                 "@id": "_1159",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1159",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1024",
#                 "@id": "_1160",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1160",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1024",
#                 "@id": "_1161",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1161",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1024",
#                 "@id": "_1162",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1162",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1024",
#                 "@id": "_1163",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1163",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1024",
#                 "@id": "_1164",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1164",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1037",
#                 "@id": "_1165",
#                 "target": "_1039"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1165",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1026",
#                 "@id": "_1166",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1166",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1026",
#                 "@id": "_1167",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1167",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1026",
#                 "@id": "_1168",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1168",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1026",
#                 "@id": "_1169",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1169",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1028",
#                 "@id": "_1170",
#                 "target": "_1030"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1170",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1028",
#                 "@id": "_1171",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1171",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1028",
#                 "@id": "_1172",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1172",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1030",
#                 "@id": "_1173",
#                 "target": "_1032"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1173",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1030",
#                 "@id": "_1174",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1174",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1134",
#                 "@id": "_1175",
#                 "target": "_1136"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1175",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1032",
#                 "@id": "_1176",
#                 "target": "_1034"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1176",
#                 "relationship": "-"
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1089",
#                 "property": "subnet_finder_score",
#                 "value": 0.0015914592805729001
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1024",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1004",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1000",
#                 "property": "subnet_finder_score",
#                 "value": 0.0017739480193314
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1001",
#                 "property": "subnet_finder_score",
#                 "value": 0.0017739480193314
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1071",
#                 "property": "subnet_finder_score",
#                 "value": 0.0008053058586865
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1020",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1070",
#                 "property": "subnet_finder_score",
#                 "value": 0.0008053058586865
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1039",
#                 "property": "subnet_finder_score",
#                 "value": 0.0010526758161814999
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1036",
#                 "property": "subnet_finder_score",
#                 "value": 0.0010526758161814999
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1010",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1028",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1030",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1136",
#                 "property": "subnet_finder_score",
#                 "value": 0.0014165852876364998
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1037",
#                 "property": "subnet_finder_score",
#                 "value": 0.0008557480251304999
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1133",
#                 "property": "subnet_finder_score",
#                 "value": 0.0014165852876364998
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1086",
#                 "property": "subnet_finder_score",
#                 "value": 0.0008623118651865001
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1003",
#                 "property": "subnet_finder_score",
#                 "value": 0.0007995669293655
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1032",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1014",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1016",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1018",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1134",
#                 "property": "subnet_finder_score",
#                 "value": 0.0014165852876364998
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1087",
#                 "property": "subnet_finder_score",
#                 "value": 0.0011063418767974999
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1012",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1034",
#                 "property": "subnet_finder_score",
#                 "value": 0.000782633370629
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1026",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1006",
#                 "property": "subnet_finder_score",
#                 "value": 0.000838832275138
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1022",
#                 "property": "subnet_finder_score",
#                 "value": 0.000819002969415
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1008",
#                 "property": "subnet_finder_score",
#                 "value": 0.0008017906401445
#             }
#         ]
#     }
# ]

# %%
# Cleanup the job (remove result)
# TODO

# %% [markdown]
# ## Sample 2: Create kernel from SIF file

# %%
# Specify locations of the SIF files
sif_file_locations = [small_network, med_network]

kernel_generation_tasks = {}

for sif_location in sif_file_locations:
    body = {
        'network_url': sif_location
    }
    res = requests.post(BASE + 'services/kernel', json=body, headers=HEADERS)
    kernel_generation_tasks[sif_location] = res.json()['job_id']
    jprint(res.json())
# Out:
# {
#     "status": "queued",
#     "job_id": "e72c389c-b4e1-4ce8-ba79-9fbd6bc32020"
# }
# {
#     "status": "queued",
#     "job_id": "32663c01-fc9d-4383-a418-6b8bdd5db23e"
# }

# %%
# Check the status of the job
res = requests.get(BASE + 'queue')
jprint(res.json())
# Out:
# [
#     {
#         "status": "finished",
#         "job_id": "8d129cd8-82e7-46ea-8a6b-29860d9bfdbe"
#     },
#     {
#         "status": "finished",
#         "job_id": "41a9d88a-e856-47a6-ae93-de8c2f2f1785"
#     },
#     {
#         "status": "finished",
#         "job_id": "94de8f58-0ebb-4728-860a-04dbe8e9de83"
#     },
#     {
#         "status": "finished",
#         "job_id": "c55846a3-ecf4-4f6f-bd08-3142b29bf587"
#     },
#     {
#         "status": "finished",
#         "job_id": "1ff8b863-16ea-44fc-8933-2269fb35cd41"
#     },
#     {
#         "status": "finished",
#         "job_id": "e9a83b0c-7c5a-4289-9d36-4e36c55df3d9"
#     },
#     {
#         "status": "finished",
#         "job_id": "95917928-e1d0-47b8-b8d2-cfbd2e319856"
#     },
#     {
#         "status": "finished",
#         "job_id": "62cae9ca-a2a1-4830-946f-6e7573bc6330"
#     },
#     {
#         "status": "finished",
#         "job_id": "d4f51901-1c02-4dca-8e2e-8b9458a6dac5"
#     },
#     {
#         "status": "finished",
#         "job_id": "2d133f66-3989-45b6-ba93-09edc7c6943d"
#     },
#     {
#         "status": "finished",
#         "job_id": "c802f315-8bf7-4326-baca-8a45878ef7e6"
#     },
#     {
#         "status": "finished",
#         "job_id": "5dc2d677-1af0-4940-85d9-b95730c40c10"
#     },
#     {
#         "status": "finished",
#         "job_id": "f58a297c-75a2-413f-8194-7be296f5ccd5"
#     },
#     {
#         "status": "finished",
#         "job_id": "8199e3bb-2f69-441e-b9eb-56855eedf9a8"
#     },
#     {
#         "status": "finished",
#         "job_id": "d36919ac-dc70-4d83-b8ab-993fc8c453f2"
#     },
#     {
#         "status": "finished",
#         "job_id": "8602c7c1-e797-47b2-96b4-5dd56969950c"
#     },
#     {
#         "status": "finished",
#         "job_id": "02a764a4-ec8e-4144-a56c-d1c030f84064"
#     },
#     {
#         "status": "finished",
#         "job_id": "73064068-c178-4881-b1a8-abb12c8fc54a"
#     },
#     {
#         "status": "finished",
#         "job_id": "aa4e18f7-0e57-4612-a4d6-2ffd821f95c3"
#     },
#     {
#         "status": "finished",
#         "job_id": "57b7535a-44ce-41a6-b1e3-018321166bd8"
#     },
#     {
#         "status": "finished",
#         "job_id": "27e1b322-2b34-4a9f-862d-b27f3e0ad7cc"
#     },
#     {
#         "status": "finished",
#         "job_id": "8a3807c5-eb30-417a-96c1-4758802bfa7d"
#     },
#     {
#         "status": "finished",
#         "job_id": "8fb0fb65-3856-467a-aad2-5dd27350d634"
#     },
#     {
#         "status": "finished",
#         "job_id": "d88d52f1-0b80-4b02-9d28-5a325b86a012"
#     },
#     {
#         "status": "finished",
#         "job_id": "9bb21570-a63c-447f-888e-37f419238ab6"
#     },
#     {
#         "status": "finished",
#         "job_id": "e72c389c-b4e1-4ce8-ba79-9fbd6bc32020"
#     },
#     {
#         "status": "finished",
#         "job_id": "da0f42c2-63ed-48c8-9c25-f5d51099fd2c"
#     },
#     {
#         "status": "finished",
#         "job_id": "6b625f52-d8f6-4177-96d9-beae6f9eb665"
#     },
#     {
#         "status": "finished",
#         "job_id": "74424d06-c0b6-4795-bed5-608170fc6c8f"
#     },
#     {
#         "status": "finished",
#         "job_id": "e5877f8f-269e-42cf-98f9-cd2ea4573cc1"
#     },
#     {
#         "status": "finished",
#         "job_id": "0102cc86-186d-45f9-b28a-5ffb24b7bcd8"
#     },
#     {
#         "status": "finished",
#         "job_id": "e5533b71-d2c8-4b19-9616-b154ea2c2deb"
#     },
#     {
#         "status": "finished",
#         "job_id": "79fdffc5-d6bc-48c2-9e74-f71c0293b6ff"
#     },
#     {
#         "status": "finished",
#         "job_id": "254ef0ca-9369-45c9-a9b2-0a44c36267ce"
#     },
#     {
#         "status": "finished",
#         "job_id": "3443af8b-7a94-4368-914c-dd1071106eac"
#     },
#     {
#         "status": "finished",
#         "job_id": "52729626-33a7-4c69-8d5e-52c56fb2c1f6"
#     },
#     {
#         "status": "finished",
#         "job_id": "69e1ad5c-9fe2-4a00-8fce-eb14b1d331e5"
#     },
#     {
#         "status": "finished",
#         "job_id": "20fe772a-9473-4952-9b84-b8eb646e0a57"
#     },
#     {
#         "status": "finished",
#         "job_id": "a6ce6c5a-8920-4016-a831-27d1962b7183"
#     },
#     {
#         "status": "finished",
#         "job_id": "77cdcbdd-dbfe-4c0d-bafb-fc275f359073"
#     },
#     {
#         "status": "finished",
#         "job_id": "641f7adf-1c14-4855-af86-e0f5ccde894a"
#     },
#     {
#         "status": "finished",
#         "job_id": "813873ea-ebb9-4bbb-8c5f-236071ab9547"
#     },
#     {
#         "status": "finished",
#         "job_id": "0d7730c7-753e-4be9-a0d5-7199def06ea8"
#     },
#     {
#         "status": "finished",
#         "job_id": "3d943f57-4093-4849-964b-1f1c5154a94d"
#     },
#     {
#         "status": "finished",
#         "job_id": "a9efca80-eaeb-4aa4-8778-578706f3cc8b"
#     },
#     {
#         "status": "finished",
#         "job_id": "73f70e2e-fd8e-4a3d-ae75-a3a9165d6088"
#     },
#     {
#         "status": "finished",
#         "job_id": "20c1a969-5ead-4c4e-8273-1de14db92b8e"
#     },
#     {
#         "status": "finished",
#         "job_id": "40d67924-6ca4-4cfc-b937-1d360a9ffa02"
#     },
#     {
#         "status": "running",
#         "job_id": "32663c01-fc9d-4383-a418-6b8bdd5db23e"
#     },
#     {
#         "status": "finished",
#         "job_id": "d66ce983-1f5b-4611-a84f-3f6b71406d56"
#     },
#     {
#         "status": "finished",
#         "job_id": "903480e9-80b8-4225-b693-9f4435419061"
#     },
#     {
#         "status": "finished",
#         "job_id": "67a24087-650e-4ee2-876e-b203d34f6bfe"
#     },
#     {
#         "status": "finished",
#         "job_id": "1479b85b-002c-4cfc-8540-626dc6182dc5"
#     },
#     {
#         "status": "finished",
#         "job_id": "0bb2f7c6-d76a-4149-bc20-47466bcb2706"
#     },
#     {
#         "status": "finished",
#         "job_id": "fc7ffe4a-9e66-4bb0-baf5-2e37e672ad06"
#     },
#     {
#         "status": "finished",
#         "job_id": "465df758-8b2f-4470-bd6b-cc055e38686a"
#     },
#     {
#         "status": "finished",
#         "job_id": "875adfc5-dc51-4ac7-904d-826198ff634a"
#     },
#     {
#         "status": "finished",
#         "job_id": "a4d5b62d-e3fd-428f-a473-4de6b189d2e5"
#     },
#     {
#         "status": "finished",
#         "job_id": "51dd6285-36b3-445e-837d-5a72cb671d06"
#     },
#     {
#         "status": "finished",
#         "job_id": "e9e7dd85-079c-44a2-a2f0-d93261fad68e"
#     },
#     {
#         "status": "finished",
#         "job_id": "dcf0e6fb-4922-45ef-a644-cf96fae8a3f1"
#     },
#     {
#         "status": "finished",
#         "job_id": "a7c1fffc-9dad-4a10-a14b-bab116cad445"
#     },
#     {
#         "status": "finished",
#         "job_id": "6f023dbb-28f5-4f28-be22-89d749d2621f"
#     },
#     {
#         "status": "finished",
#         "job_id": "c6e6b792-792b-451f-ad43-594df242bf17"
#     },
#     {
#         "status": "finished",
#         "job_id": "a8e9d9d7-818d-4c75-a31e-3b5c60fb1683"
#     },
#     {
#         "status": "finished",
#         "job_id": "89484385-a01a-4d21-a108-5d58818b2f24"
#     },
#     {
#         "status": "finished",
#         "job_id": "230e5611-773d-4854-99d3-45f09269f469"
#     },
#     {
#         "status": "finished",
#         "job_id": "fea71d1e-4c59-461c-b36a-d6f686fb3b23"
#     },
#     {
#         "status": "finished",
#         "job_id": "0ec436a7-b8e7-42c9-8cfb-0a816d176915"
#     },
#     {
#         "status": "finished",
#         "job_id": "9cd4b027-052d-49ea-9c0f-c6b3cb8b328e"
#     },
#     {
#         "status": "finished",
#         "job_id": "ff4bf9af-04a3-4963-9095-cd9461bcea79"
#     },
#     {
#         "status": "finished",
#         "job_id": "dc2a4a2f-ef91-4e4a-9dd1-df12543c15c5"
#     },
#     {
#         "status": "finished",
#         "job_id": "7c08e65e-774c-4c83-b02b-2810728ea947"
#     },
#     {
#         "status": "finished",
#         "job_id": "4a2c89ea-6aec-4d7e-91f5-26df10b55bcd"
#     },
#     {
#         "status": "finished",
#         "job_id": "fee8bdee-aaf2-4915-919b-92a5bbcbe1a1"
#     },
#     {
#         "status": "finished",
#         "job_id": "016aeb41-7c6a-4301-b678-75234cf525c6"
#     },
#     {
#         "status": "finished",
#         "job_id": "7d53143f-14da-4ee4-885c-cdba3b33aa69"
#     },
#     {
#         "status": "finished",
#         "job_id": "1b073220-b7e7-4154-b061-e08dc6e5c3f0"
#     },
#     {
#         "status": "finished",
#         "job_id": "1fccd8a6-637f-43a8-b72c-66971fc8bfae"
#     },
#     {
#         "status": "finished",
#         "job_id": "5b307403-36d8-40af-b75a-142cc77f9d24"
#     },
#     {
#         "status": "finished",
#         "job_id": "43a947b2-5626-48d8-9060-d71c9010d3a1"
#     },
#     {
#         "status": "finished",
#         "job_id": "488e0039-7167-4d06-b2ee-92253904c75a"
#     },
#     {
#         "status": "finished",
#         "job_id": "1e838496-78b4-4e34-8d61-53e500ccdf33"
#     },
#     {
#         "status": "finished",
#         "job_id": "8ba4fec6-c017-4dfc-a89e-758eb135b600"
#     },
#     {
#         "status": "finished",
#         "job_id": "7f160fb4-d944-42fa-81d6-98c8a6b0c1f6"
#     },
#     {
#         "status": "finished",
#         "job_id": "17ef92d3-24bf-4340-bb96-9688435b9482"
#     },
#     {
#         "status": "finished",
#         "job_id": "1fb72670-7dd2-474e-a619-6593fdccadb2"
#     },
#     {
#         "status": "finished",
#         "job_id": "9f6e2019-fbe8-4076-9f80-b82befbe2b62"
#     },
#     {
#         "status": "finished",
#         "job_id": "db5cd140-33a8-4ba8-baec-55e9d7625d40"
#     },
#     {
#         "status": "finished",
#         "job_id": "ee50d5b9-21c6-4052-95c9-bab41b0ab1cf"
#     },
#     {
#         "status": "finished",
#         "job_id": "58a291d6-e2b9-4749-a60f-a29ffe9fa1ec"
#     },
#     {
#         "status": "finished",
#         "job_id": "35e62680-db08-49fb-855c-6c8ed6566dd2"
#     },
#     {
#         "status": "finished",
#         "job_id": "e2fabbbe-432b-4213-9ab5-e5117fbe814f"
#     },
#     {
#         "status": "finished",
#         "job_id": "91946857-a3c5-4ba2-aa42-39d89a7b04d4"
#     },
#     {
#         "status": "finished",
#         "job_id": "d94de941-0f60-45a4-a8d6-6be8cd91cffd"
#     },
#     {
#         "status": "finished",
#         "job_id": "890ff0ce-07b2-4f65-b051-d81c92844116"
#     },
#     {
#         "status": "finished",
#         "job_id": "0b27f18c-4d4c-40d8-8fc1-6defcd8f4456"
#     },
#     {
#         "status": "finished",
#         "job_id": "c5f4acc4-70c3-4cb2-8e81-03aa7088f182"
#     },
#     {
#         "status": "finished",
#         "job_id": "f1e5b5a3-8b4e-4985-9a83-04788442d9aa"
#     },
#     {
#         "status": "finished",
#         "job_id": "76d91d4a-9073-4130-9c88-79b6e9e13da3"
#     },
#     {
#         "status": "finished",
#         "job_id": "7e315766-846d-461a-8dba-d70861136a2c"
#     },
#     {
#         "status": "finished",
#         "job_id": "fa257b3b-683c-4fe1-9532-6a7d03bd814f"
#     }
# ]

# %%
# Get result
job_id_for_small_network = kernel_generation_tasks[small_network]

kernel_url = BASE + 'queue/' + job_id_for_small_network
print(kernel_url)
res = requests.get(kernel_url)
kernel_info = res.json()
jprint(kernel_info)
# Out:
# http://192.168.99.100/v1/queue/e72c389c-b4e1-4ce8-ba79-9fbd6bc32020
# {
#     "kernel_id": "bca3c2b8-7436-47ec-a89f-937ec84b5d19",
#     "kernel_file": "http://kernelserver:3000/data/df2aa870-46c3-11e5-b8c6-395d86e177f7",
#     "network": "https://s3-us-west-2.amazonaws.com/ci-service-data/small.sif"
# }

# %%
# Use the result to find subnetwork
base_query = {
    'kernel_url': kernel_info['kernel_file'],
    'network_url': kernel_info['network']
}

gene_list = ["NRAS", "KRAS", "MAPK1"]
base_query['query'] = gene_list

for i in range(0, 100):
    res = requests.post(BASE + 'services/subnet', data=json.dumps(base_query), headers=HEADERS)
    find_subnet_job_id = res.json()['job_id']
#     jprint(res.json())

# %%
# Check the result
result_url = BASE + 'queue/' + find_subnet_job_id
print(result_url)
res = requests.get(result_url)
jprint(res.json())
# Out:
# http://192.168.99.100/v1/queue/9f6e2019-fbe8-4076-9f80-b82befbe2b62
# [
#     {
#         "nodes": [
#             {
#                 "@id": "_1000"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1000",
#                 "represents": "RASAL1"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1001"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1001",
#                 "represents": "NRAS"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1000",
#                 "@id": "_1002",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1002",
#                 "relationship": "DIRECTLY_DECREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1003"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1003",
#                 "represents": "RASA2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1003",
#                 "@id": "_1004",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1004",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1005"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1005",
#                 "represents": "GK"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1005",
#                 "@id": "_1006",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1006",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1007"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1007",
#                 "represents": "KRAS"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1008"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1008",
#                 "represents": "KRAS"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1007",
#                 "@id": "_1009",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1009",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1010"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1010",
#                 "represents": "HNRNPA2B1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1011",
#                 "target": "_1010"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1011",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1012"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1012",
#                 "represents": "CHEBI:N-acetylsphingosine"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1012",
#                 "@id": "_1013",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1013",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1014"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1014",
#                 "represents": "ITGA1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1015",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1015",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1016"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1016",
#                 "represents": "ITGA5"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1017",
#                 "target": "_1016"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1017",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1018"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1018",
#                 "represents": "CHEBI:glutathione"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1019",
#                 "target": "_1018"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1019",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1020"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1020",
#                 "represents": "PSMC6"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1021",
#                 "target": "_1020"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1021",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1022"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1022",
#                 "represents": "RPS6KB1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1023",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1023",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1024"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1024",
#                 "represents": "HNRNPD"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1025",
#                 "target": "_1024"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1025",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1026"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1026",
#                 "represents": "MESHD:Adenoma"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1027",
#                 "target": "_1026"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1027",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1028"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1028",
#                 "represents": "ITGB1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1029",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1029",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1030",
#                 "target": "_1028"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1030",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1031"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1031",
#                 "represents": "DAB2IP"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1031",
#                 "@id": "_1032",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1032",
#                 "relationship": "DIRECTLY_DECREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1033",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1033",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1034",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1034",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1035"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1035",
#                 "represents": "ERBB4"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1036",
#                 "target": "_1035"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1036",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1037"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1037",
#                 "represents": "ICMT"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1037",
#                 "@id": "_1038",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1038",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1039",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1039",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1040"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1040",
#                 "represents": "ETS1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1041",
#                 "target": "_1040"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1041",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1042"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1042",
#                 "represents": "DYRK1B"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1043",
#                 "target": "_1042"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1043",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1044"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1044",
#                 "represents": "ETFB"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1045",
#                 "target": "_1044"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1045",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1046",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1046",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1047",
#                 "target": "_1022"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1047",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1048"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1048",
#                 "represents": "ANXA1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1049",
#                 "target": "_1048"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1049",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1050",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1050",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1051"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1051",
#                 "represents": "ITGA3"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1052",
#                 "target": "_1051"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1052",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1053",
#                 "target": "_1008"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1053",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1054"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1054",
#                 "represents": "RASSF2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1055",
#                 "target": "_1054"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1055",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1056"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1056",
#                 "represents": "BGN"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1057",
#                 "target": "_1056"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1057",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1058"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1058",
#                 "represents": "AKT1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1059",
#                 "target": "_1058"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1059",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1060"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1060",
#                 "represents": "SCHEM:Dinoprostone"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1061",
#                 "target": "_1060"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1061",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1062",
#                 "target": "_1054"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1062",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1001",
#                 "@id": "_1063",
#                 "target": "_1001"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1063",
#                 "relationship": "DIRECTLY_INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1064"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1064",
#                 "represents": "PPIB"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1065",
#                 "target": "_1064"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1065",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1066",
#                 "target": "_1014"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1066",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1067"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1067",
#                 "represents": "ST6GAL1"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1068",
#                 "target": "_1067"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1068",
#                 "relationship": "INCREASES"
#             }
#         ]
#     },
#     {
#         "nodes": [
#             {
#                 "@id": "_1069"
#             }
#         ]
#     },
#     {
#         "nodeIdentities": [
#             {
#                 "node": "_1069",
#                 "represents": "SF3A2"
#             }
#         ]
#     },
#     {
#         "edges": [
#             {
#                 "source": "_1008",
#                 "@id": "_1070",
#                 "target": "_1069"
#             }
#         ],
#         "edgeIdentities": [
#             {
#                 "edge": "_1070",
#                 "relationship": "DECREASES"
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1005",
#                 "property": "subnet_finder_score",
#                 "value": 0.0229954133663028
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1051",
#                 "property": "subnet_finder_score",
#                 "value": 0.008752657101589333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1016",
#                 "property": "subnet_finder_score",
#                 "value": 0.008752657101589333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1020",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1028",
#                 "property": "subnet_finder_score",
#                 "value": 0.008752657101589333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1000",
#                 "property": "subnet_finder_score",
#                 "value": 0.02185291821396733
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1060",
#                 "property": "subnet_finder_score",
#                 "value": 0.008752657101589333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1012",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1069",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1037",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1022",
#                 "property": "subnet_finder_score",
#                 "value": 0.02960808230170333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1014",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1044",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1031",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1018",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1024",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1067",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1040",
#                 "property": "subnet_finder_score",
#                 "value": 0.008752657101589333
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1056",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1035",
#                 "property": "subnet_finder_score",
#                 "value": 0.02185291821396733
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1054",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1064",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1010",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1048",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1026",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1058",
#                 "property": "subnet_finder_score",
#                 "value": 0.021615276117601
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1042",
#                 "property": "subnet_finder_score",
#                 "value": 0.008419448144810134
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1008",
#                 "property": "subnet_finder_score",
#                 "value": 0.015527753540395
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1001",
#                 "property": "subnet_finder_score",
#                 "value": 0.17266687540099995
#             }
#         ]
#     },
#     {
#         "elementProperties": [
#             {
#                 "node": "_1003",
#                 "property": "subnet_finder_score",
#                 "value": 0.0229954133663028
#             }
#         ]
#     }
# ]

# %% [markdown]
# ## Test API: simple community detection service

# %%
subnet_query = {
    'kernel_url': kernel_info['kernel_file'],
    'network_url': kernel_info['network'],
    'query':  ["NRAS", "KRAS", "MAPK1"]
}

for i in range(0, 10):
    res = requests.post(BASE + 'services/subnet', data=json.dumps(subnet_query), headers=HEADERS)
    print(json.dumps(res.json(), indent=4))

# %%
kernel = {
    'name': 'small2',
    'kernel_url': kernel_info['kernel_file'],
    'network_url': kernel_info['network']
}
res = requests.post(BASE + 'services/subnetfinder', data=json.dumps(kernel), headers=HEADERS)
print(json.dumps(res.json(), indent=4))

# %%
query = {
    'query':  ["NRAS", "KRAS", "MAPK1"]
}
res = requests.post(BASE + 'services/subnetfinder/small2', data=json.dumps(query), headers=HEADERS)
# print(json.dumps(res.json(), indent=4))
print(len(res.json()))

# %%
# Finder test
from hdsubnetfinder.subnetwork.sub_network_finder import SubNetworkFinder
from hdsubnetfinder.kernel.kernel_generator import KernelGenerator

generator = KernelGenerator()
kernel = generator.create_kernel_from_file("http://52.26.237.67:3333/data/765c6530-45fc-11e5-8b3f-7f6daa1cad6f")
finder = SubNetworkFinder(kernel=kernel, network="https://s3-us-west-2.amazonaws.com/ci-service-data/small.sif")

# %%
subnet = finder.get_sub_network(["NRAS", "KRAS", "MAPK1"])
print(subnet)

# %%
original = res.content

# %%
import pandas as pd
import StringIO
file1 = StringIO.StringIO(original)

df = pd.read_csv(file1, sep="\t")
len(df)

df.head()
